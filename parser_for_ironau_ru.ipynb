# %% [markdown]
# <a href="https://colab.research.google.com/github/MeikoFudo/PROJECT_IT_SCHOOL/blob/main/parser_for_ironau_ru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
from bs4 import BeautifulSoup

# папка для сохранения файлов с текстом
folder_path = "parsed_texts"

# создаем папку, если она еще не существует
if not os.path.exists(folder_path):
    os.mkdir(folder_path)

# читаем файл с ссылками
with open("all_corrent_links.txt", "r") as f:
    links = [line.strip() for line in f.readlines()]

# проходимся по ссылкам и парсим текст
for i, link in enumerate(links):
    try:
        response = requests.get(link)
        response.encoding = 'windows-1251'
        soup = BeautifulSoup(response.text, 'html.parser')
        textDiv = soup.find('td', class_='white').find('div', class_='text')

        # сохраняем текст в файл
        file_name = f"parsed_text_{i}.txt"
        with open(os.path.join(folder_path, file_name), "w") as f:
            f.write(textDiv.text.strip())
            
        print(f"Ссылка {link} успешно спарсена и сохранена в файл {file_name}")
    except:
        print(f"Ошибка при парсинге ссылки {link}")
# Out:
# Ссылка https://ironau.ru/salamgeri.html успешно спарсена и сохранена в файл parsed_text_0.txt
# Ссылка https://ironau.ru/fxudync.html успешно спарсена и сохранена в файл parsed_text_1.txt
# Ссылка https://ironau.ru/allon.html успешно спарсена и сохранена в файл parsed_text_2.txt
# Ссылка https://ironau.ru/cavsa.html успешно спарсена и сохранена в файл parsed_text_3.txt
# Ссылка https://ironau.ru/osetin.html успешно спарсена и сохранена в файл parsed_text_4.txt
# Ссылка https://ironau.ru/gusalty.html успешно спарсена и сохранена в файл parsed_text_5.txt
# Ссылка https://ironau.ru/anekdot1.html успешно спарсена и сохранена в файл parsed_text_6.txt
# Ссылка https://ironau.ru/anekdot2.html успешно спарсена и сохранена в файл parsed_text_7.txt
# Ссылка https://ironau.ru/anekdot3.html успешно спарсена и сохранена в файл parsed_text_8.txt
# Ссылка https://ironau.ru/anekdot4.html успешно спарсена и сохранена в файл parsed_text_9.txt
# ...

# %%
import zipfile
import os

zipfile_name = 'parsed_texts.zip'
folder_path = '/content/parsed_texts'
with zipfile.ZipFile(zipfile_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            zipf.write(os.path.join(root, file))

# Скачиваем архив в текущую директорию
from google.colab import files
files.download(zipfile_name)
